# %%
import pandas as pd

# %%
kospi100=pd.read_csv("/Users/lucy/Downloads/복사본 KRX100재무주가.csv")

# %%
per100=pd.read_csv("/Users/lucy/Downloads/전종목_PER_PBR_20221103.csv")

# %%
per100
# Out:
#         종목코드       종목명      종가     대비    등락률    EPS    PER 선행 EPS 선행 PER  \
# 0     060310       3S    2,405    -50  -2.04     33  72.88      -      -
# 1     095570   AJ네트웍스    6,160     80   1.32  1,707   3.61    861   7.16
# 2     006840    AK홀딩스   12,000    300   2.56      -      -      -      -
# 3     054620   APS홀딩스   11,500   -100  -0.86  1,179   9.75      -      -
# 4     265520    AP시스템   17,050      0   0.00  3,932   4.34  3,833   4.45
# ...      ...       ...     ...    ...    ...    ...    ...    ...    ...
# 2489  000547  흥국화재2우B   19,550   -700  -3.46      -      -      -      -
# 2490  000545    흥국화재우    6,200   -230  -3.58      -      -      -      -
# 2491  003280     흥아해운    1,445    -50  -3.34    118  12.25      -      -
# 2492  037440       희림   11,850  2,480  26.47    490  24.18      -      -
# 2493  238490       힘스    5,800    -20  -0.34      -      -      -      -
#
#          BPS   PBR 주당배당금  배당수익률
# 0        829  2.90     0   0.00
# ...

# %%
kospi100
# Out:
#            Symbol  A005930 A005930.1   A373220 A373220.1   A207940 A207940.1  \
# 0     Symbol Name     삼성전자      삼성전자  LG에너지솔루션  LG에너지솔루션  삼성바이오로직스  삼성바이오로직스
# 1       Item Name  수정주가(원)     종가(원)   수정주가(원)     종가(원)   수정주가(원)     종가(원)
# 2      2010-01-04   16,180   809,000       NaN       NaN       NaN       NaN
# 3      2010-01-05   16,440   822,000       NaN       NaN       NaN       NaN
# 4      2010-01-06   16,820   841,000       NaN       NaN       NaN       NaN
# ...           ...      ...       ...       ...       ...       ...       ...
# 3162   2022-10-25   57,700    57,700   511,000   511,000   884,000   884,000
# 3163   2022-10-26   59,400    59,400   529,000   529,000   896,000   896,000
# 3164   2022-10-27   59,500    59,500   540,000   540,000   873,000   873,000
# 3165   2022-10-28   57,300    57,300   532,000   532,000   876,000   876,000
# 3166   2022-10-31   59,400    59,400   528,000   528,000   877,000   877,000
#
# ...

# %%
# per100의 종목명과 kospi100의 첫번째 행을 inner join해야 한다

# %%
#kospi100의 첫번째 행만 남겨두고 이걸 열로 바꿔보자

# %%
kospi100=kospi100.T # 전치시켜서 바꿈

# %%
kospi100
# Out:
#                   0          1           2           3           4     \
# Symbol     Symbol Name  Item Name  2010-01-04  2010-01-05  2010-01-06
# A005930           삼성전자    수정주가(원)      16,180      16,440      16,820
# A005930.1         삼성전자      종가(원)     809,000     822,000     841,000
# A373220       LG에너지솔루션    수정주가(원)         NaN         NaN         NaN
# A373220.1     LG에너지솔루션      종가(원)         NaN         NaN         NaN
# ...                ...        ...         ...         ...         ...
# A196170.1         알테오젠      종가(원)         NaN         NaN         NaN
# A035760         CJ ENM    수정주가(원)     141,934     142,675     143,970
# A035760.1       CJ ENM      종가(원)      76,700      77,100      77,800
# A096530             씨젠    수정주가(원)         NaN         NaN         NaN
# A096530.1           씨젠      종가(원)         NaN         NaN         NaN
#
#                  5           6           7           8           9     ...  \
# ...

# %%
kospi100=kospi100[[0]]

# %%
kospi100
# Out:
#                      0
# Symbol     Symbol Name
# A005930           삼성전자
# A005930.1         삼성전자
# A373220       LG에너지솔루션
# A373220.1     LG에너지솔루션
# ...                ...
# A196170.1         알테오젠
# A035760         CJ ENM
# A035760.1       CJ ENM
# A096530             씨젠
# A096530.1           씨젠
#
# [201 rows x 1 columns]

# %%
kospi100.rename(columns={0:'종목명'},inplace=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
kospi100
# Out:
#                    종목명
# Symbol     Symbol Name
# A005930           삼성전자
# A005930.1         삼성전자
# A373220       LG에너지솔루션
# A373220.1     LG에너지솔루션
# ...                ...
# A196170.1         알테오젠
# A035760         CJ ENM
# A035760.1       CJ ENM
# A096530             씨젠
# A096530.1           씨젠
#
# [201 rows x 1 columns]

# %%
# 중복제거
kospi100=kospi100.drop_duplicates(['종목명'])

# %%
kospi100['종목명']
# Out:
# Symbol     Symbol Name
# A005930           삼성전자
# A373220       LG에너지솔루션
# A207940       삼성바이오로직스
# A000660         SK하이닉스
#               ...
# A042660         대우조선해양
# A006360           GS건설
# A196170           알테오젠
# A035760         CJ ENM
# A096530             씨젠
# Name: 종목명, Length: 101, dtype: object

# %%
#per100과 innerjoin을 하고 이걸 새로운 데이트프레임 kospi100per에 저장한다

# %%
# 이렇게 되면 kospi100의 per을 가진 csv 추출이 가능해진다

# %%
kospi100per=pd.merge(kospi100,per100,on="종목명", how="outer")

# %%
df_LEFT_JOIN = pd.merge(per100, kospi100, left_on='종목명', right_on='종목명', how='left')
df_LEFT_JOIN
df_LEFT_JOIN.to_csv("df_LEFT_JOIN.csv")

# %%
kospi100per
# Out:
#         index          종목명    종목코드      종가     대비    등락률  EPS    PER 선행 EPS  \
# 0      Symbol  Symbol Name     NaN     NaN    NaN    NaN  NaN    NaN    NaN
# 1     A005930         삼성전자     NaN     NaN    NaN    NaN  NaN    NaN    NaN
# 2     A373220     LG에너지솔루션     NaN     NaN    NaN    NaN  NaN    NaN    NaN
# 3     A207940     삼성바이오로직스     NaN     NaN    NaN    NaN  NaN    NaN    NaN
# 4     A000660       SK하이닉스     NaN     NaN    NaN    NaN  NaN    NaN    NaN
# ...       ...          ...     ...     ...    ...    ...  ...    ...    ...
# 2590      NaN     흥국화재2우B   000547  19,550   -700  -3.46    -      -      -
# 2591      NaN       흥국화재우   000545   6,200   -230  -3.58    -      -      -
# 2592      NaN        흥아해운   003280   1,445    -50  -3.34  118  12.25      -
# 2593      NaN          희림   037440  11,850  2,480  26.47  490  24.18      -
# 2594      NaN          힘스   238490   5,800    -20  -0.34    -      -      -
#
#      선행 PER    BPS   PBR 주당배당금  배당수익률
# ...

# %%
kospi100per.to_csv("kospi100per.csv")

# %%
tmpA=per100.join(kospi100,how='left')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-e3be104bd785> in <module>
# ----> 1 tmpA=per100.join(kospi100,how='left')
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9097         5  K5  A5  NaN
#    9098         """
# -> 9099         return self._join_compat(
#    9100             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9101         )
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9128                     sort=sort,
#    9129                 )
# -> 9130             return merge(
#    9131                 self,
#    9132                 other,
#
# ...

# %%
kospi100per
# Out:
# Empty DataFrame
# Columns: [종목명, 종목코드, 종가, 대비, 등락률, EPS, PER, 선행 EPS, 선행 PER, BPS, PBR, 주당배당금, 배당수익률]
# Index: []

# %%
per100['종목명']
# Out:
# 0            3S
# 1        AJ네트웍스
# 2         AK홀딩스
# 3        APS홀딩스
# 4         AP시스템
#           ...
# 2489    흥국화재2우B
# 2490      흥국화재우
# 2491       흥아해운
# 2492         희림
# 2493         힘스
# Name: 종목명, Length: 2494, dtype: object

# %%
kospi100['종목명']
# Out:
# Symbol     Symbol Name
# A005930           삼성전자
# A373220       LG에너지솔루션
# A207940       삼성바이오로직스
# A000660         SK하이닉스
#               ...
# A042660         대우조선해양
# A006360           GS건설
# A196170           알테오젠
# A035760         CJ ENM
# A096530             씨젠
# Name: 종목명, Length: 101, dtype: object

# %%
#kospi100
kospi100=kospi100.rename_axis('index').reset_index()

# %%
per100
# Out:
#         종목코드       종목명      종가     대비    등락률    EPS    PER 선행 EPS 선행 PER  \
# 0     060310       3S    2,405    -50  -2.04     33  72.88      -      -
# 1     095570   AJ네트웍스    6,160     80   1.32  1,707   3.61    861   7.16
# 2     006840    AK홀딩스   12,000    300   2.56      -      -      -      -
# 3     054620   APS홀딩스   11,500   -100  -0.86  1,179   9.75      -      -
# 4     265520    AP시스템   17,050      0   0.00  3,932   4.34  3,833   4.45
# ...      ...       ...     ...    ...    ...    ...    ...    ...    ...
# 2489  000547  흥국화재2우B   19,550   -700  -3.46      -      -      -      -
# 2490  000545    흥국화재우    6,200   -230  -3.58      -      -      -      -
# 2491  003280     흥아해운    1,445    -50  -3.34    118  12.25      -      -
# 2492  037440       희림   11,850  2,480  26.47    490  24.18      -      -
# 2493  238490       힘스    5,800    -20  -0.34      -      -      -      -
#
#          BPS   PBR 주당배당금  배당수익률
# 0        829  2.90     0   0.00
# ...

# %%
kospi100
# Out:
#        index          종목명
# 0     Symbol  Symbol Name
# 1    A005930         삼성전자
# 2    A373220     LG에너지솔루션
# 3    A207940     삼성바이오로직스
# 4    A000660       SK하이닉스
# ..       ...          ...
# 96   A042660       대우조선해양
# 97   A006360         GS건설
# 98   A196170         알테오젠
# 99   A035760       CJ ENM
# 100  A096530           씨젠
#
# [101 rows x 2 columns]

# %%
# per100 전체 탐색
# per100의 종목명이 Kospi100 종목명과 같다면
# csv100에 write한다
# 그렇지 않다면 continue한다

"""
import csv    
f = open('output.csv', 'w', encoding='utf-8', newline='')
wr = csv.writer(f)
wr.writerow([1, "김정수", False])
wr.writerow([2, "박상미", True])
f.close()
"""
# Out:
# '\nimport csv    \nf = open(\'output.csv\', \'w\', encoding=\'utf-8\', newline=\'\')\nwr = csv.writer(f)\nwr.writerow([1, "김정수", False])\nwr.writerow([2, "박상미", True])\nf.close()\n'

# %%
import csv

# %%
#f = open('output.csv', 'w', encoding='utf-8', newline='')

# %%
kospi100_arr=[]
for i in range(1,101):
    print(kospi100['종목명'][i])
    kospi100_arr.append(str(kospi100['종목명'][i]))
# Out:
# 삼성전자
# LG에너지솔루션
# 삼성바이오로직스
# SK하이닉스
# 삼성SDI
# LG화학
# 현대차
# 기아
# 셀트리온
# NAVER
# 삼성물산
# 카카오
# POSCO홀딩스
# 현대모비스
# KB금융
# 신한지주
# SK
# SK이노베이션
# 포스코케미칼
# 삼성생명
# LG전자
# KT&G
# LG
# 고려아연
# 하나금융지주
# 에코프로비엠
# SK텔레콤
# 한국전력
# 셀트리온헬스케어
# S-Oil
# 현대중공업
# 삼성화재
# KT
# 삼성에스디에스
# 한화솔루션
# HMM
# 삼성전기
# 두산에너빌리티
# 우리금융지주
# 크래프톤
# 대한항공
# 엔씨소프트
# 엘앤에프
# LG생활건강
# 기업은행
# 카카오뱅크
# LG이노텍
# 현대글로비스
# CJ제일제당
# SK바이오사이언스
# F&F
# 아모레퍼시픽
# SK스퀘어
# 한국조선해양
# 롯데케미칼
# 강원랜드
# LG유플러스
# 하이브
# HD현대
# 삼성엔지니어링
# 삼성중공업
# HLB
# 카카오페이
# 한국타이어앤테크놀로지
# LG디스플레이
# SK바이오팜
# 한국항공우주
# 유한양행
# GS
# 한온시스템
# 코웨이
# 오리온
# DB손해보험
# SKC
# 미래에셋증권
# 현대건설
# 금호석유
# 현대제철
# 넷마블
# SK아이이테크놀로지
# 메리츠화재
# 두산밥캣
# 한국가스공사
# 카카오게임즈
# 한미약품
# 에스디바이오센서
# 삼성증권
# 호텔신라
# 한국금융지주
# 일진머티리얼즈
# 펄어비스
# 셀트리온제약
# OCI
# 이마트
# 팬오션
# 대우조선해양
# GS건설
# 알테오젠
# CJ ENM
# 씨젠

# %%
#kospi100_arr
for i in range(len(kospi100_arr)):
    print(kospi100_arr[i])
# Out:
# 삼성전자
# LG에너지솔루션
# 삼성바이오로직스
# SK하이닉스
# 삼성SDI
# LG화학
# 현대차
# 기아
# 셀트리온
# NAVER
# 삼성물산
# 카카오
# POSCO홀딩스
# 현대모비스
# KB금융
# 신한지주
# SK
# SK이노베이션
# 포스코케미칼
# 삼성생명
# LG전자
# KT&G
# LG
# 고려아연
# 하나금융지주
# 에코프로비엠
# SK텔레콤
# 한국전력
# 셀트리온헬스케어
# S-Oil
# 현대중공업
# 삼성화재
# KT
# 삼성에스디에스
# 한화솔루션
# HMM
# 삼성전기
# 두산에너빌리티
# 우리금융지주
# 크래프톤
# 대한항공
# 엔씨소프트
# 엘앤에프
# LG생활건강
# 기업은행
# 카카오뱅크
# LG이노텍
# 현대글로비스
# CJ제일제당
# SK바이오사이언스
# F&F
# 아모레퍼시픽
# SK스퀘어
# 한국조선해양
# 롯데케미칼
# 강원랜드
# LG유플러스
# 하이브
# HD현대
# 삼성엔지니어링
# 삼성중공업
# HLB
# 카카오페이
# 한국타이어앤테크놀로지
# LG디스플레이
# SK바이오팜
# 한국항공우주
# 유한양행
# GS
# 한온시스템
# 코웨이
# 오리온
# DB손해보험
# SKC
# 미래에셋증권
# 현대건설
# 금호석유
# 현대제철
# 넷마블
# SK아이이테크놀로지
# 메리츠화재
# 두산밥캣
# 한국가스공사
# 카카오게임즈
# 한미약품
# 에스디바이오센서
# 삼성증권
# 호텔신라
# 한국금융지주
# 일진머티리얼즈
# 펄어비스
# 셀트리온제약
# OCI
# 이마트
# 팬오션
# 대우조선해양
# GS건설
# 알테오젠
# CJ ENM
# 씨젠

# %%
for i in range(100):
    print(per100['종목명'][i])
# Out:
# 3S
# AJ네트웍스
# AK홀딩스
# APS홀딩스
# AP시스템
# AP위성
# BGF
# BGF리테일
# BNGT
# BNK금융지주
# BYC
# BYC우
# CBI
# CJ
# CJ CGV
# CJ ENM
# CJ 바이오사이언스
# CJ4우(전환)
# CJ대한통운
# CJ씨푸드
# CJ씨푸드1우
# CJ우
# CJ제일제당
# CJ제일제당 우
# CJ프레시웨이
# CMG제약
# CNH
# CNT85
# CS
# CSA 코스믹
# CS홀딩스
# DB
# DB금융스팩10호
# DB금융스팩8호
# DB금융스팩9호
# DB금융투자
# DB손해보험
# DB하이텍
# DB하이텍1우
# DGB금융지주
# DI동일
# DL
# DL건설
# DL우
# DL이앤씨
# DL이앤씨2우(전환)
# DL이앤씨우
# DMS
# DN오토모티브
# DRB동일
# DSC인베스트먼트
# DSR
# DSR제강
# E1
# EDGC
# EG
# ES큐브
# EV수성
# F&F
# F&F홀딩스
# FSN
# GH신소재
# GKL
# GS
# GST
# GS건설
# GS글로벌
# GS리테일
# GS우
# HB솔루션
# HB테크놀러지
# HDC
# HDC랩스
# HDC현대EP
# HDC현대산업개발
# HD현대
# HJ중공업
# HK이노엔
# HL D&I
# HLB
# HLB글로벌
# HLB생명과학
# HLB제약
# HLB테라퓨틱스
# HL만도
# HL홀딩스
# HMM
# HPSP
# HRS
# HSD엔진
# IBKS제13호스팩
# IBKS제16호스팩
# IBKS제17호스팩
# IBKS제18호스팩
# IBKS제19호스팩
# IBKS제20호스팩
# IHQ
# ISC
# ITX-AI
# JB금융지주

# %%
per100.iloc[1]
# Out:
# 종목코드       095570
# 종목명       AJ네트웍스
# 종가          6,160
# 대비             80
# 등락률          1.32
# EPS         1,707
# PER          3.61
# 선행 EPS        861
# 선행 PER       7.16
# BPS         8,075
# PBR          0.76
# 주당배당금         270
# 배당수익률        4.38
# Name: 1, dtype: object

# %%
import csv    
f = open('output.csv', 'w', encoding='utf-8', newline='')
wr = csv.writer(f)
wr.writerow([1, "김정수", False])
wr.writerow([2, "박상미", True])
f.close()

# %%
#kospi100_arr :kospi100 종목명 담겨있음
import csv    
f = open('output.csv', 'w', encoding='utf-8', newline='')
wr=csv.writer(f)
for i in range(2494):
    #per100['종목명'][i]
    #print("'"+per100['종목명'][i].strip()+"'")
    if (per100['종목명'][i].strip()) in kospi100_arr:
        print('참')
        print(per100.iloc[i])
        wr.writerow(per100.iloc[i])
        
    else:
        continue
f.close()
# Out:
# 참
# 종목코드       035760
# 종목명       CJ ENM
# 종가         73,800
# 대비         -2,400
# 등락률         -3.15
# EPS         9,332
# PER          7.91
# 선행 EPS      7,576
# 선행 PER       9.74
# BPS       182,220
# PBR          0.41
# 주당배당금       2,100
# 배당수익률        2.85
# Name: 15, dtype: object
# 참
# 종목코드       097950
# 종목명       CJ제일제당
# 종가        427,000
# 대비           -500
# 등락률         -0.12
# EPS        38,246
# PER         11.16
# 선행 EPS     50,232
# 선행 PER       8.50
# BPS       381,542
# PBR          1.12
# 주당배당금       5,000
# 배당수익률        1.17
# Name: 22, dtype: object
# 참
# 종목코드       005830
# 종목명       DB손해보험
# 종가         56,300
# 대비         -1,300
# 등락률         -2.26
# EPS        14,482
# PER          3.89
# 선행 EPS     11,963
# 선행 PER       4.71
# BPS       110,605
# PBR          0.51
# 주당배당금       3,500
# 배당수익률        6.22
# Name: 36, dtype: object
# 참
# 종목코드       383220
# 종목명          F&F
# 종가        143,000
# 대비         -3,500
# 등락률         -2.39
# EPS         6,061
# ...

# %%
'삼성전자' in kospi100_arr
# Out:
# True

# %%
if (per100['종목명'][922].strip()) in kospi100_arr:
    print('참')
else:
    print('거짓')
# Out:
# 참

# %%
per100['종목명'][922].strip() in kospi100_arr
# Out:
# True

# %%
("'"+per100['종목명'][30].strip()+"'") in kospi100_arr
# Out:
# False

# %%
a=['a','b','c']

# %%
if 'a' in a:
    print("참")
# Out:
# 참

# %%
pd.read_csv('output.csv', columns=[''])
# Out:
#     035760  CJ ENM    73,800  -2,400  -3.15   9,332   7.91   7,576   9.74  \
# 0    97950  CJ제일제당   427,000    -500  -0.12  38,246  11.16  50,232   8.50
# 1     5830  DB손해보험    56,300  -1,300  -2.26  14,482   3.89  11,963   4.71
# 2   383220     F&F   143,000  -3,500  -2.39   6,061  23.59  13,887  10.30
# 3    78930      GS    46,100    -300  -0.65  15,304   3.01  18,055   2.55
# 4     6360    GS건설    22,250    -350  -1.55   4,834   4.60   5,728   3.88
# ..     ...      ...      ...     ...    ...     ...    ...     ...    ...
# 94   12330   현대모비스   218,500    -500  -0.23  25,645   8.52  34,377   6.36
# 95    4020    현대제철    29,150    -250  -0.85  11,110   2.62   8,836   3.30
# 96  329180   현대중공업   111,000  -1,000  -0.89       -      -   2,428  45.72
# 97    5380     현대차   162,000  -3,000  -1.82  18,979   8.54  30,151   5.37
# 98    8770    호텔신라    62,700  -1,800  -2.79     714  87.82   2,693  23.28
#
#     182,220   0.41  2,100  2.85
# 0   381,542   1.12  5,000  1.17
# ...

# %%
pd.read_csv('/Users/lucy/Downloads/PERKOSPI100/PERKOSPI100.csv')
# Out:
#       종목코드      종목명       종가      대비   등락률     EPS    PER  선행 EPS 선행 PER  \
# 0    35760  CJ ENM    73,800  -2,400 -3.15   9,332   7.91   7,576   9.74
# 1    97950  CJ제일제당   427,000    -500 -0.12  38,246  11.16  50,232   8.50
# 2     5830  DB손해보험    56,300  -1,300 -2.26  14,482   3.89  11,963   4.71
# 3   383220     F&F   143,000  -3,500 -2.39   6,061  23.59  13,887  10.30
# 4    78930      GS    46,100    -300 -0.65  15,304   3.01  18,055   2.55
# ..     ...      ...      ...     ...   ...     ...    ...     ...    ...
# 95   12330   현대모비스   218,500    -500 -0.23  25,645   8.52  34,377   6.36
# 96    4020    현대제철    29,150    -250 -0.85  11,110   2.62   8,836   3.30
# 97  329180   현대중공업   111,000  -1,000 -0.89       -      -   2,428  45.72
# 98    5380     현대차   162,000  -3,000 -1.82  18,979   8.54  30,151   5.37
# 99    8770    호텔신라    62,700  -1,800 -2.79     714  87.82   2,693  23.28
#
#         BPS    PBR  주당배당금  배당수익률
# 0   182,220   0.41  2,100   2.85
# ...
